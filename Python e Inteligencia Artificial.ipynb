# %%
from google.colab import userdata
userdata.get('GEMINI_API_KEY')
# Out:
# 'AIzaSyAXmtZ5xqcj1RN3t51aoF6eceTNRdHMhwk'

# %%
from google.colab import userdata
userdata.get('GEMINI_API_KEY')
# Out:
# 'AIzaSyAXmtZ5xqcj1RN3t51aoF6eceTNRdHMhwk'

# %%
from google.colab import userdata
userdata.get('GEMINI_API_KEY')

os.
# Out:
#   File "/tmp/ipython-input-2456969092.py", line 4
#     os.
#        ^
# SyntaxError: invalid syntax

# %%
import os
from google.colab import userdata

os.environ['GOOGLE_API_KEY'] = userdata.get('GEMINI_API_KEY')

# %%
from google import genai

client = genai.Client()

# %%
client.models.generate_content(model='gemini-3-flash-preview', contents="O que e a inteligencia artificial?")
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""A **Inteligência Artificial (IA)** é um campo da ciência da computação que se dedica a criar sistemas, máquinas e softwares capazes de simular a capacidade humana de raciocinar, aprender, tomar decisões e resolver problemas.
#
# Em termos simples, a IA permite que computadores "pensem" de forma lógica, processando grandes volumes de dados para identificar padrões e realizar tarefas que, antes, eram exclusivas dos seres humanos.
#
# Aqui estão os pontos principais para entender como ela funciona e onde ela está:
#
# ---
#
# ### 1. Como a IA funciona?
# Ao contrário de um programa de computador tradicional (que segue uma lista rígida de instruções "se acontecer A, faça B"), a IA moderna baseia-se em:
# ...

# %%
resposta = client.models.generate_content(model='gemini-3-flash-preview', contents="O que e a inteligencia artificial?")

# %%
print(resposta.text)
# Out:
# A **Inteligência Artificial (IA)** é um campo da ciência da computação que se dedica a criar sistemas e tecnologias capazes de realizar tarefas que, normalmente, exigiriam **inteligência humana**.
#
# Em termos simples, é a capacidade de uma máquina "pensar", aprender, raciocinar e tomar decisões de forma autônoma, baseando-se em padrões de dados.
#
# Aqui estão os pontos principais para entender o que é a IA:
#
# ### 1. Como ela funciona?
# Diferente de um software tradicional (onde um programador escreve regras fixas do tipo "se acontecer A, faça B"), a IA utiliza **algoritmos** e grandes volumes de dados (**Big Data**) para aprender por conta própria.
# *   **Aprendizado de Máquina (Machine Learning):** É o método mais comum. O sistema analisa milhares de exemplos para identificar padrões e melhorar seu desempenho com o tempo.
# ...

# %%
n = 1

while n <= 500:
  print("*")
  n = n + 1
# Out:
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# ...

# %%
n = 1

while n <= 10:
  print("*")
  n = n + 1
# Out:
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *

# %%
chat = client.chats.create(model="gemini-3-flash-preview")

# %%
respostas = chat.send_message('O que e inteligencia artificial?')

# %%
print(respostas.text)
# Out:
# A **Inteligência Artificial (IA)** é um campo da ciência da computação que se dedica a criar sistemas e máquinas capazes de realizar tarefas que, normalmente, exigiriam **inteligência humana**.
#
# Em termos simples, a IA permite que computadores "aprendam" com dados, reconheçam padrões e tomem decisões ou resolvam problemas de forma autônoma.
#
# Aqui estão os pontos principais para entender como ela funciona e onde ela está:
#
# ### 1. Como a IA funciona?
# Diferente de um programa de computador tradicional, que segue uma lista rígida de instruções (se acontecer A, faça B), a IA utiliza **algoritmos** e grandes volumes de dados para treinar a si mesma. Os conceitos principais são:
#
# *   **Aprendizado de Máquina (Machine Learning):** É a capacidade da máquina de melhorar seu desempenho em uma tarefa à medida que é exposta a mais dados, sem ser explicitamente programada para cada detalhe.
# ...

# %%
rs = chat.send_message('Quando foi lancando o chatGPT?')

# %%
print(rs.text)
# Out:
# O ChatGPT foi lançado oficialmente no dia **30 de novembro de 2022**.
#
# Ele foi desenvolvido pela empresa **OpenAI**, com sede em San Francisco, nos Estados Unidos.
#
# Aqui estão alguns detalhes interessantes sobre o lançamento:
#
# 1.  **Sucesso Imediato:** O ChatGPT se tornou um dos aplicativos de crescimento mais rápido da história, atingindo 1 milhão de usuários em apenas cinco dias após o lançamento.
# 2.  **Modelo Inicial:** Quando foi lançado em novembro de 2022, ele utilizava uma versão otimizada do modelo de linguagem **GPT-3.5**.
# 3.  **GPT-4:** Em março de 2023, a OpenAI lançou o GPT-4, uma versão muito mais poderosa e capaz, disponível para assinantes do ChatGPT Plus.
# 4.  **Objetivo:** O lançamento foi feito inicialmente como um "protótipo" para que o público pudesse testar e a OpenAI pudesse coletar feedbacks para tornar a IA mais segura e útil.
#
# ...

# %%
prompt = input("Digite a sua pergunta: ")

while prompt != "fim":
# Out:
#   File "/tmp/ipython-input-170816291.py", line 3
#     while prompt != "fim":
#                           ^
# SyntaxError: incomplete input

# %%
prompt = input("Digite a sua pergunta: ")

while prompt != "fim":
  res = chat.send_message(prompt)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3949621459.py in <cell line: 0>()
# ----> 1 prompt = input("Digite a sua pergunta: ")
#       2
#       3 while prompt != "fim":
#       4   res = chat.send_message(prompt)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
prompt = input("Digite a sua pergunta: ")

while prompt != "fim":
  res = chat.send_message(prompt)
  print(prompt.text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2160347928.py in <cell line: 0>()
# ----> 1 prompt = input("Digite a sua pergunta: ")
#       2
#       3 while prompt != "fim":
#       4   res = chat.send_message(prompt)
#       5   print(prompt.text)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
res = input("Digite a sua pergunta: ")

while res != "fim":
  res = chat.send_message(prompt)
  print(res.text)
  res = input("Digite a sua pergunta: ")
# Out:
# Digite a sua pergunta: ola
# Olá! Estou aqui. 😊
#
# Parece que estamos apenas trocando cumprimentos! Tudo bem com você?
#
# Como posso ser útil agora? Se quiser, podemos continuar falando sobre tecnologia, ou posso te ajudar com alguma outra coisa, como:
#
# 1.  **Criar algo:** Um texto, um e-mail, uma lista de tarefas ou até um código.
# 2.  **Explicar algo:** Algum tema de história, ciência ou curiosidades.
# 3.  **Traduzir:** Posso traduzir frases para outros idiomas.
# 4.  **Dicas:** Sugestões de filmes, livros ou planos de estudo.
#
# O que você tem em mente?
# Digite a sua pergunta: tudo e com voce?
# Olá novamente! 😊
#
# Parece que entramos em um pequeno "loop" de saudações! Tudo bem com você?
#
# Já que já nos cumprimentamos bastante, que tal darmos o próximo passo? Posso te ajudar com alguma dúvida, te contar uma curiosidade ou até mesmo criar algo para você.
#
# **O que você gostaria de fazer agora?**
# *   Quer saber mais sobre como eu (a IA) funciono?
# ...

# %%
res = input("Digite a sua pergunta: ")

while res != "fim":
  res = chat.send_message(prompt)
  print(res.text)
  print("\n")
  res = input("Digite a sua pergunta: ")
# Out:
# Digite a sua pergunta: ola
# Olá! 👋
#
# Parece que estamos batendo um recorde de "olás" hoje! 😂
#
# Tudo bem com você? Estou aqui pronto para ajudar assim que você precisar. Se você estiver apenas testando para ver se eu respondo sempre, a resposta é **sim, estou aqui e pronto para conversar!**
#
# Se quiser que eu faça algo específico, é só dizer. Caso contrário, **olá mais uma vez!** 😊
#
# Como posso ser útil agora?
#
#
# Digite a sua pergunta: fim

# %%
lista_de_nome = ["João Silva", "Maria Oliveira", "Ana Paula Santos", "Carlos Eduardo Pereira", "Fernanda Costa"]

# %%
lista_de_nome[3]
# Out:
# 'Carlos Eduardo Pereira'

# %%
print(lista_de_nome[3])
# Out:
# Carlos Eduardo Pereira

# %%
lista_de_medias = [8.9, 7.5, 4.2, 1.4, 9.5]

# %%
n = 0

while n < 5:
  lista_de_medias[n] = lista_de_medias[n] + 1
  n = n + 1
