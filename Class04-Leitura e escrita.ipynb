# %%
#Lendo e escrevendo em Python

emails = [
    {
        "assunto": "Atualização rápida",
        "corpo": "Oi,\nSó para avisar que a atualização já foi concluída.\nAbraços"
    },
    {
        "assunto": "Alinhamento",
        "corpo": "Olá,\nPodemos alinhar esse ponto ainda hoje?\nObrigado!"
    },
    {
        "assunto": "Lembrete",
        "corpo": "Oi,\nPassando para lembrar do combinado.\nValeu!"
    },
    {
        "assunto": "Bom dia",
        "corpo": "Bom dia,\nEspero que esteja tudo bem por aí.\nAbraços"
    },
    {
        "assunto": "Seguimento",
        "corpo": "Olá,\nDando seguimento à nossa última conversa.\nAbs"
    },
    {
        "assunto": "Confirmação",
        "corpo": "Oi,\nPode confirmar se recebeu a mensagem anterior?\nObrigado"
    },
    {
        "assunto": "Sugestão",
        "corpo": "Olá,\nTive uma sugestão que pode ajudar.\nAbraço"
    },
    {
        "assunto": "Tudo certo?",
        "corpo": "Oi,\nSó checando se está tudo certo.\nValeu!"
    },
    {
        "assunto": "Próximos passos",
        "corpo": "Olá,\nQuando puder, me diga como prefere seguir.\nObrigado!"
    },
    {
        "assunto": "Encerramento",
        "corpo": "Oi,\nEtapa finalizada por aqui. Seguimos em contato.\nAbraços"
    }
]

# %%
lista_de_resumos = []

for email in emails:
    resumo = f"{email['assunto']}: {email['corpo']}"
    lista_de_resumos.append(resumo)

with open("resumos.txt", "w", encoding="utf-8") as arquivo:
    for resumo in lista_de_resumos:
        arquivo.write(resumo + "\n")

# %%
import pandas as pd

# %%
pd.read_csv("/content/meu_csv.csv", sep=":")
# Out:
#      nome,media
# 0       Ana,7.5
# 1    Carlos,8.2
# 2   Beatriz,9.1
# 3     Diogo,6.8
# 4   Eduarda,5.9
# 5  Fernanda,8.5
# 6   Gustavo,7.3
# 7    Helena,9.5
# 8      Igor,6.1
# 9   Juliana,8.9

# %%
lista_de_perguntas = []

# %%
lista_de_perguntas = [
    "De que feito o sol?",
    "De que feito a lua?",
    "De que feito o planeta terra?",
    "De que feito as estrelas?",
]

# %%
import os
from google.colab import userdata

# %%
os.environ["GOOGLE_API_KEY"] = userdata.get('Alura_Python')

# %%
from google import genai

client = genai.Client()
