# %% [markdown]
# # Módulo 4

# %% [markdown]
# ### Lendo e escrevendo em arquivos usando Python

# %%
with open("lista-de-resumos.txt", "w", encoding="utf-8") as arquivo:
    for resumo in lista_resumos:
        arquivo.write(resumo + "\n")

# %%
nova_lista_de_leitura = []

with open("lista-de-resumos.txt", "r", encoding="utf-8") as arquivo:
    for linha in arquivo:
        nova_lista_de_leitura.append(linha.strip())

# %%
nova_lista_de_leitura
# Out:
# ['E-mail 1: A reunião de planejamento foi remarcada para sexta-feira às 10h; favor confirmar presença.',
#  'E-mail 2: **Atualização de sistema na madrugada de sábado para domingo pode deixar a plataforma indisponível por algumas horas.**',
#  'E-mail 3: Carlos está fazendo um follow-up sobre o relatório enviado, para garantir que a análise seja finalizada até o fim da semana.',
#  'E-mail 4: Lembrete: O prazo final para a entrega dos holerites de dezembro é na próxima segunda-feira.',
#  'E-mail 5: Confirmamos o recebimento do seu pedido #12345, que já está em processamento, e o código de rastreamento será enviado em breve.',
#  'E-mail 6: Pedido de férias de 15 dias com início em 20 de agosto.',
#  'E-mail 7: Agradecemos sua participação no webinar e enviamos o material completo.',
#  'E-mail 8: Sua fatura mensal já está disponível para acesso e pagamento.',
#  'E-mail 9: Lúcia convida Ana para almoçar na quarta-feira em um novo restaurante perto do escritório.',
#  'E-mail 10: **Solicitação de orçamento para a compra de 500 unidades do produto X.**',
#  'E-mail 11: Convite para entrevista de Desenvolvedor Júnior, solicitando a disponibilidade do candidato.',
#  'E-mail 12: Comunicado sobre problemas técnicos na rede e o trabalho da equipe para normalizar o serviço o mais rápido possível.',
#  'E-mail 13: Confirmação da reunião de amanhã às 14h para discutir a proposta de projeto.',
#  'E-mail 14: Oferta de 10% de desconto para a próxima compra na loja online, utilizando o cupom DESCONTO10.',
#  'E-mail 15: Convite para a festa de confraternização da empresa no dia 15 de dezembro no Salão de Eventos.',
#  'E-mail 16: Confirmação do processamento do cancelamento de sua assinatura.',
#  'E-mail 17: **Solicitação para adiar o prazo de entrega do projeto A para a próxima semana, devido a contratempos.**',
#  'E-mail 18: Liberação do relatório de desempenho mensal para análise da equipe de vendas e envio de comentários até o final da semana.',
#  'E-mail 19: Lembrete da reunião de pais: quinta-feira, às 19h, na quadra da escola, com presença fundamental.',
#  'E-mail 20: Convite para workshop de IA em 30/09: inscreva-se já, vagas limitadas.']

# %%
conteudo = ""

with open("lista-de-resumos.txt", "r", encoding="utf-8") as arquivo:
    conteudo = arquivo.read()

# %%
conteudo
# Out:
# 'E-mail 1: A reunião de planejamento foi remarcada para sexta-feira às 10h; favor confirmar presença.\nE-mail 2: **Atualização de sistema na madrugada de sábado para domingo pode deixar a plataforma indisponível por algumas horas.**\nE-mail 3: Carlos está fazendo um follow-up sobre o relatório enviado, para garantir que a análise seja finalizada até o fim da semana.\nE-mail 4: Lembrete: O prazo final para a entrega dos holerites de dezembro é na próxima segunda-feira.\nE-mail 5: Confirmamos o recebimento do seu pedido #12345, que já está em processamento, e o código de rastreamento será enviado em breve.\nE-mail 6: Pedido de férias de 15 dias com início em 20 de agosto.\nE-mail 7: Agradecemos sua participação no webinar e enviamos o material completo.\nE-mail 8: Sua fatura mensal já está disponível para acesso e pagamento.\nE-mail 9: Lúcia convida Ana para almoçar na quarta-feira em um novo restaurante perto do escritório.\nE-mail 10: **Solicitação de orçamento para a compra de 500 unidades do produto X.**\nE-mail 11: Convite para entrevista de Desenvolvedor Júnior, solicitando a disponibilidade do candidato.\nE-mail 12: Comunicado sobre problemas técnicos na rede e o trabalho da equipe para normalizar o serviço o mais rápido possível.\nE-mail 13: Confirmação da reunião de amanhã às 14h para discutir a proposta de projeto.\nE-mail 14: Oferta de 10% de desconto para a próxima compra na loja online, utilizando o cupom DESCONTO10.\nE-mail 15: Convite para a festa de confraternização da empresa no dia 15 de dezembro no Salão de Eventos.\nE-mail 16: Confirmação do processamento do cancelamento de sua assinatura.\nE-mail 17: **Solicitação para adiar o prazo de entrega do projeto A para a próxima semana, devido a contratempos.**\nE-mail 18: Liberação do relatório de desempenho mensal para análise da equipe de vendas e envio de comentários até o final da semana.\nE-mail 19: Lembrete da reunião de pais: quinta-feira, às 19h, na quadra da escola, com presença fundamental.\nE-mail 20: Convite para workshop de IA em 30/09: inscreva-se já, vagas limitadas.\n'

# %%
nova_lista_de_leitura_2 = []

with open("lista-de-resumos.txt", "r", encoding="utf-8") as arquivo:
    nova_lista_de_leitura_2 = arquivo.readlines()

# %%
nova_lista_de_leitura_2
# Out:
# ['E-mail 1: A reunião de planejamento foi remarcada para sexta-feira às 10h; favor confirmar presença.\n',
#  'E-mail 2: **Atualização de sistema na madrugada de sábado para domingo pode deixar a plataforma indisponível por algumas horas.**\n',
#  'E-mail 3: Carlos está fazendo um follow-up sobre o relatório enviado, para garantir que a análise seja finalizada até o fim da semana.\n',
#  'E-mail 4: Lembrete: O prazo final para a entrega dos holerites de dezembro é na próxima segunda-feira.\n',
#  'E-mail 5: Confirmamos o recebimento do seu pedido #12345, que já está em processamento, e o código de rastreamento será enviado em breve.\n',
#  'E-mail 6: Pedido de férias de 15 dias com início em 20 de agosto.\n',
#  'E-mail 7: Agradecemos sua participação no webinar e enviamos o material completo.\n',
#  'E-mail 8: Sua fatura mensal já está disponível para acesso e pagamento.\n',
#  'E-mail 9: Lúcia convida Ana para almoçar na quarta-feira em um novo restaurante perto do escritório.\n',
#  'E-mail 10: **Solicitação de orçamento para a compra de 500 unidades do produto X.**\n',
#  'E-mail 11: Convite para entrevista de Desenvolvedor Júnior, solicitando a disponibilidade do candidato.\n',
#  'E-mail 12: Comunicado sobre problemas técnicos na rede e o trabalho da equipe para normalizar o serviço o mais rápido possível.\n',
#  'E-mail 13: Confirmação da reunião de amanhã às 14h para discutir a proposta de projeto.\n',
#  'E-mail 14: Oferta de 10% de desconto para a próxima compra na loja online, utilizando o cupom DESCONTO10.\n',
#  'E-mail 15: Convite para a festa de confraternização da empresa no dia 15 de dezembro no Salão de Eventos.\n',
#  'E-mail 16: Confirmação do processamento do cancelamento de sua assinatura.\n',
#  'E-mail 17: **Solicitação para adiar o prazo de entrega do projeto A para a próxima semana, devido a contratempos.**\n',
#  'E-mail 18: Liberação do relatório de desempenho mensal para análise da equipe de vendas e envio de comentários até o final da semana.\n',
#  'E-mail 19: Lembrete da reunião de pais: quinta-feira, às 19h, na quadra da escola, com presença fundamental.\n',
#  'E-mail 20: Convite para workshop de IA em 30/09: inscreva-se já, vagas limitadas.\n']

# %% [markdown]
# ### Manipulando dados com Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/meu_csv.csv")

# %%
df.head()
# Out:
#       nome  media
# 0      Ana    7.5
# 1   Carlos    8.2
# 2  Beatriz    9.1
# 3    Diogo    6.8
# 4  Eduarda    5.9

# %%
df.tail()
# Out:
#        nome  media
# 5  Fernanda    8.5
# 6   Gustavo    7.3
# 7    Helena    9.5
# 8      Igor    6.1
# 9   Juliana    8.9

# %% [markdown]
# Desafio:
# 1. Criar um arquivo .txt a partir de uma lista de perguntas vindas de uma lista em Python [].
# 2. Ler as perguntas desse arquivo .txt e salvá-las em uma lista Python
# 3. Obter respostas de um LLM para cada uma.
# 4. Salvar os resultados em um novo arquivo .csv
# 5. Ler o arquivo .csv usando Pandas

# %%
# Etapa 1
lista_de_perguntas = [
    "De que é feito o Sol?",
    "De que é feito o planeta Saturno?",
    "Qual é a galáxia mais antiga já encontrada?",
    "Qual é a maior estrela já encontrada?",
    "Qual é a estrela mais próxima do Sol?"
]

with open("perguntas.txt", "w", encoding="utf-8") as arquivo:
    for pergunta in lista_de_perguntas:
        arquivo.write(pergunta + "\n")

# %%
# Etapa 2
lista_desafio = []

with open("perguntas.txt", "r", encoding="utf-8") as arquivo:
    for linha in arquivo:
        lista_desafio.append(linha.strip())

print(lista_desafio)
# Out:
# ['De que é feito o Sol?', 'De que é feito o planeta Saturno?', 'Qual é a galáxia mais antiga já encontrada?', 'Qual é a maior estrela já encontrada?', 'Qual é a estrela mais próxima do Sol?']

# %%
# Etapa 3
lista_de_dicionarios_de_respostas = []

for pergunta in lista_desafio:
    resposta = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=f"Gere uma resposta muito sucinta para a pergunta: {pergunta}"
        )
    lista_de_dicionarios_de_respostas.append({"pergunta":pergunta, "resposta":resposta.text})

# %%
lista_de_dicionarios_de_respostas
# Out:
# [{'pergunta': 'De que é feito o Sol?', 'resposta': 'Hidrogênio e hélio.'},
#  {'pergunta': 'De que é feito o planeta Saturno?',
#   'resposta': 'Gases, principalmente hidrogênio e hélio.'},
#  {'pergunta': 'Qual é a galáxia mais antiga já encontrada?',
#   'resposta': 'JADES-GS-z14-0.'},
#  {'pergunta': 'Qual é a maior estrela já encontrada?',
#   'resposta': 'UY Scuti.'},
#  {'pergunta': 'Qual é a estrela mais próxima do Sol?',
#   'resposta': 'Próxima Centauri.'}]

# %%
# Etapa 4
with open("respostas1.csv", "w", encoding="utf-8") as arquivo:
    arquivo.write("pergunta,resposta\n")
    for pergunta_dict in lista_de_dicionarios_de_respostas:
        arquivo.write(f"{pergunta_dict['pergunta']},{pergunta_dict['resposta']}\n")

# %%
df_perguntas_e_respostas = pd.DataFrame(lista_de_dicionarios_de_respostas)

# %%
df_perguntas_e_respostas
# Out:
#                                       pergunta  \
# 0                        De que é feito o Sol?
# 1            De que é feito o planeta Saturno?
# 2  Qual é a galáxia mais antiga já encontrada?
# 3        Qual é a maior estrela já encontrada?
# 4        Qual é a estrela mais próxima do Sol?
#
#                                     resposta
# 0                        Hidrogênio e hélio.
# 1  Gases, principalmente hidrogênio e hélio.
# 2                            JADES-GS-z14-0.
# 3                                  UY Scuti.
# 4                          Próxima Centauri.

# %%
df_perguntas_e_respostas.to_csv("resposta2.csv", index=False, encoding="utf-8")

# %%
# Etapa 5
novo_df = pd.read_csv("resposta2.csv")

# %%
novo_df
# Out:
#                                       pergunta  \
# 0                        De que é feito o Sol?
# 1            De que é feito o planeta Saturno?
# 2  Qual é a galáxia mais antiga já encontrada?
# 3        Qual é a maior estrela já encontrada?
# 4        Qual é a estrela mais próxima do Sol?
#
#                                     resposta
# 0                        Hidrogênio e hélio.
# 1  Gases, principalmente hidrogênio e hélio.
# 2                            JADES-GS-z14-0.
# 3                                  UY Scuti.
# 4                          Próxima Centauri.
